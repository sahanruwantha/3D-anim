# %% [markdown]
# # 3D Animation / Parallax Maker
#
# Run this notebook to use the Parallax Maker with a cloud GPU.
#
# **Instructions:**
# 1. Go to Runtime > Change runtime type > Select **T4 GPU**
# 2. Run all cells in order
# 3. Click the ngrok link at the bottom to access the web UI

# %%
# Check GPU
# !nvidia-smi

# %%
# Clone the repository
# !git clone https://github.com/sahanruwantha/3D-anim.git
# %cd 3D-anim

# %%
# Install dependencies (ignore warnings about Colab's pre-installed packages)
# !pip install --upgrade pip -q
# !pip install -e . --no-deps -q

# Install core dependencies explicitly
# !pip install dash dash-extensions flask werkzeug pillow opencv-python-headless -q
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121 -q
# !pip install transformers accelerate diffusers safetensors -q
# !pip install segment-anything timm==0.6.13 -q
# !pip install pyngrok -q

print("\n" + "="*50)
print("Installation complete!")
print("="*50)

# %%
# Set up ngrok for public URL
# Get your free auth token from: https://dashboard.ngrok.com/get-started/your-authtoken
NGROK_AUTH_TOKEN = ""  # <-- Paste your ngrok token here

from pyngrok import ngrok

if NGROK_AUTH_TOKEN:
    ngrok.set_auth_token(NGROK_AUTH_TOKEN)
    public_url = ngrok.connect(8050)
    print(f"\n{'='*50}")
    print(f"Click here to open the app:")
    print(f"{public_url}")
    print(f"{'='*50}\n")
else:
    print("="*50)
    print("WARNING: Set NGROK_AUTH_TOKEN above to get a public URL")
    print("Get your free token from:")
    print("https://dashboard.ngrok.com/get-started/your-authtoken")
    print("="*50)

# %%
# Run the web UI
# !python -m parallax_maker.webui --host 0.0.0.0 --port 8050
